# %% [markdown]
# # Matplotlib

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt

# %% [markdown]
# Link to understand markers:
# https://www.freecodecamp.org/news/how-to-create-a-marker-in-matplotlib/

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y, color='red', marker='o')
#    xmin,xmax, ymin,ymax
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import pandas as pd
 
# Reading the CSV file to plot another line chart
iris = pd.read_csv("../data/iris_csv.csv")
iris
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris["class"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.shape[0]
# Out:
# 150

# %%
# Rows
#for i in range(0, iris.shape[0]):
#    print(i)

# %%
column = iris.drop(['class'], axis=1)
column
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
column = iris[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']]
column
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
iris["sepalwidth"].value_counts()
# Out:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: sepalwidth, dtype: int64

# %%
fig, ax = plt.subplots(2,2)
ax
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# #### Plotting multiple columns in one graph

# %%
list_products = []
for i in range(0,6):
    list_products.append(i)
    
print(list_products)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
iris["sepallength"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepallength, Length: 150, dtype: float64

# %%
# How complicated

# %%
# get columns to plot
#columns = iris.drop(['class'], axis=1)
#columns = iris[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']]
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot sepalwidth column
# axes - x axis and y axix
ax.plot(x_data, iris['sepalwidth'], marker="o")
# set title and legend
ax.set_title('Iris Dataset')
ax.legend(['sepalwidth'], loc= "best")

# %%
list_x = [1, 2, 3, 4]
for item in list_x:
    print(item)
# Out:
# 1
# 2
# 3
# 4

# %%
# get columns to plot
columns = iris.drop(['class'], axis=1)
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot all columns one by one using loop
for column in columns:
    ax.plot(x_data, iris[column], marker="o")
# set title and legend
ax.set_title('Iris Dataset')
ax.legend(['sepallength', 'sepalwidth', 'petallength', 'petalwidth'], loc= "best")

# %% [markdown]
# #### Task 1:
#
# ![data.PNG](attachment:data.PNG)

# %% [markdown]
# #### Output:
#
# ![line.PNG](attachment:line.PNG)

# %% [markdown]
# Double-click <b>here</b> for solution (level 1).
#
# <!-- Solution is below:
#
# import matplotlib.pyplot as plt
#
# year = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]
# unemployment_rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]
#
# plt.plot(year, unemployment_rate, color='red', marker='o')
# plt.title('unemployment rate vs year', fontsize=14)
# plt.xlabel('year', fontsize=14)
# plt.ylabel('unemployment rate', fontsize=14)
# plt.grid(True)
# plt.show()
#
# -->

# %% [markdown]
# Double-click <b>here</b> for solution (level 2).
#
# <!-- Solution is below:
#
# import matplotlib.pyplot as plt
# import pandas as pd
#
# year = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]
# unemployment_rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]
#
# my_dict = {"Unemployment Rate": unemployment_rate}
# data = pd.DataFrame(my_dict, index = year)
# data.index.name = "Year"
# print(data.index)
# print(data["Unemployment Rate"])
#
# plt.plot(data.index, data["Unemployment Rate"], color='red', marker='o')
# plt.title('unemployment rate vs year', fontsize=14)
# plt.xlabel('year', fontsize=14)
# plt.ylabel('unemployment rate', fontsize=14)
# plt.grid(True)
# plt.show()
#
# -->

# %% [markdown]
# # Seaborn

# %%
# pip install seaborn

# %%
import seaborn as sns

# %% [markdown]
# #### Plotting line chart using Seaborn

# %%
# Look how simple seaborn plots line chart

year = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]
unemployment_rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]

var = sns.lineplot(x=year, y=unemployment_rate, color="red", marker="o")
var.set(title='unemployment rate vs year', xlabel ="year", ylabel = "unemployment rate")
# Out:
# [Text(0.5, 1.0, 'unemployment rate vs year'),
#  Text(0.5, 0, 'year'),
#  Text(0, 0.5, 'unemployment rate')]

# %%
# Look how simple seaborn plots line chart

year = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]
unemployment_rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]

sns.lineplot(x=year, y=unemployment_rate, color="red", marker="o").set(title='unemployment rate vs year', xlabel ="year", ylabel = "unemployment rate")
# Out:
# [Text(0.5, 1.0, 'unemployment rate vs year'),
#  Text(0.5, 0, 'year'),
#  Text(0, 0.5, 'unemployment rate')]

# %% [markdown]
# #### Task 2:
#
# Plot the columns "sepallength", "sepalwidth", "petallength", and "petalwidth" using Seaborn.

# %% [markdown]
# #### Output:
#
# ![data-2.PNG](attachment:data-2.PNG)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Soltuion is below:
#
# # Solution:
#
#
# import seaborn as sns
#
# # get columns to plot
# columns = iris.drop(['class'], axis=1)
# # create x data
# x_data = range(0, iris.shape[0])
#
# for column in columns:
#     sns.lineplot(x=x_data, y=column, data = iris).set(title='Iris Dataset', xlabel ="Row Index", ylabel = "Columns")
#
# -->

# %% [markdown]
# #### Task 3:

# %% [markdown]
# Question: Use "sales.csv" dataset. Read the dataset.

# %% [markdown]
# Answer:

# %%
sales = pd.read_csv("../data/sales.csv")
sales
# Out:
#     Year  Sales
# 0   1991   1000
# 1   1994   1200
# 2   1996   1500
# 3   1995   1800
# 4   1997   2000
# 5   1998   1400
# 6   2010   1600
# 7   2000   1900
# 8   2001   2100
# 9   2004   2500
# 10  2013   2700
# 11  2015   3000
# 12  2019   4000
# 13  2018   5000
# 14  2020   4300
# 15  2024   3900
# 16  2023   4100

# %% [markdown]
# Question: Plot a line chart (Hint: x data will be column "Year" and y data will be column "Sales"). The line should be "lightpink" and marker "^"

# %% [markdown]
# Answer:

# %%
x = sales.loc[:,"Year"]
y = sales.loc[:,"Sales"]
plt.plot(x, y, color='lightpink', marker='^')
plt.show()
