# %% [markdown]
# # Bar Chart

# %% [markdown]
# ## Matplotlib

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt

# %%
import pandas as pd
 
# Reading the CSV file to plot a bar chart
iris = pd.read_csv("../data/Iris.csv")
iris
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# This will plot a simple bar chart
plt.bar(iris['class'], iris['sepallength'])
 
# Title to the plot
plt.title("Iris Dataset")
plt.xlabel("Class")
plt.ylabel("Sepal Length")
 
# Adding the legends
plt.legend(["bar"])
plt.show()

# %%
# This will plot a simple bar chart
plt.barh(iris['class'], iris['sepallength'])
 
# Title to the plot
plt.title("Iris Dataset")
plt.xlabel("Class")
plt.ylabel("Sepal Length")
 
# Adding the legends
plt.legend(["bar"])
plt.show()

# %% [markdown]
# ### Calculating the frequency of a category

# %%
# Reading the CSV file to plot another bar chart
amazon = pd.read_csv("../data/amazon.csv")
amazon
# Out:
#                          id product_name   brand  \
# 0      AVqkIhwDv8e3D1O-lebb          All  Amazon
# 1      AVqkIhwDv8e3D1O-lebb          All  Amazon
# 2      AVqkIhwDv8e3D1O-lebb          All  Amazon
# 3      AVqkIhwDv8e3D1O-lebb          All  Amazon
# 4      AVqkIhwDv8e3D1O-lebb          All  Amazon
# ...                     ...          ...     ...
# 34655  AVpfiBlyLJeJML43-4Tp          NaN  Amazon
# 34656  AVpfiBlyLJeJML43-4Tp          NaN  Amazon
# 34657  AVpfiBlyLJeJML43-4Tp          NaN  Amazon
# 34658  AVpfiBlyLJeJML43-4Tp          NaN  Amazon
# 34659  AVpfiBlyLJeJML43-4Tp          NaN  Amazon
#
#                                               categories  \
# 0      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...

# %%
# As seen above bar chart do not automatically calculate frequency of a category, 
# therefore, we will use pandas value_counts method to do this.

# %%
# counting the occurrence of each class of ratings (1-5)
amazon['rating'].value_counts()
# Out:
# 5.0    22896
# 4.0     8541
# 3.0     1499
# 1.0     1289
# 2.0      402
# Name: rating, dtype: int64

# %%
# count the occurrence of each class of ratings (1-5)
rating_values = amazon['rating'].value_counts() 
# get x and y data 
ratings = rating_values.index 
frequency = rating_values.values 
# create bar chart 
plt.bar(ratings, frequency) 
# set title and labels 
plt.title('Consumer Reviews of Amazon Products') 
plt.xlabel('Rating') 
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %%
sns.barplot(data = iris, x = iris['class'], y = iris['sepallength'])
# Out:
# <Axes: xlabel='class', ylabel='sepallength'>

# %% [markdown]
# # Count Chart

# %%
# Showing frequency of categorical values (1-5) in rating column
sns.countplot(x = 'rating', data = amazon)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
# Use a different colour palette in count plot
sns.countplot(x = 'rating', data = amazon, palette = "Set2")
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
# Use a different colour palette in count plot
sns.countplot(x = 'rating', data = amazon, color = "yellow")

# or:
#sns.countplot(x = 'rating', data = amazon, color = "#FFFF00")
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %% [markdown]
# #### Task:
#
# Plot a chart to show the frequency of brand using Amazon data. Change the color to "DarkMagenta" and bar width to 0.9

# %% [markdown]
# ![file.PNG](attachment:file.PNG)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Soltuion is below:
#
# import seaborn as sns
#
# sns.countplot(x = 'brand', data = amazon, color = "DarkMagenta", width = 1)
#
# # or:
# # sns.countplot(x = 'brand', data = amazon, color = "#8B008B", width = 1)
#
# -->
